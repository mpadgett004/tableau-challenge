# %%
import pandas as pd
import os

# %%
jan2020 = pd.read_csv('Resources/JC-202001-citibike-tripdata.csv')
feb2020 = pd.read_csv('Resources/JC-202002-citibike-tripdata.csv')
mar2020 = pd.read_csv('Resources/JC-202003-citibike-tripdata.csv')
april2020 = pd.read_csv('Resources/JC-202004-citibike-tripdata.csv')
may2020 = pd.read_csv('Resources/JC-202005-citibike-tripdata.csv')
june2020 = pd.read_csv('Resources/JC-202006-citibike-tripdata.csv')
july2020 = pd.read_csv('Resources/JC-202007-citibike-tripdata.csv')
aug2020 = pd.read_csv('Resources/JC-202008-citibike-tripdata.csv')
sept2020 = pd.read_csv('Resources/JC-202009-citibike-tripdata.csv')
oct2020 = pd.read_csv('Resources/JC-202010-citibike-tripdata.csv')
nov2020 = pd.read_csv('Resources/JC-202011-citibike-tripdata.csv')
dec2020 = pd.read_csv('Resources/JC-202012-citibike-tripdata.csv')

# %%
jan2020
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1               377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2               288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3               435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4               231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...             ...                       ...                       ...
# 26015           544  2020-01-31 23:29:29.3910  2020-01-31 23:38:33.6910
# 26016           122  2020-01-31 23:30:59.3670  2020-01-31 23:33:01.6870
# 26017           201  2020-01-31 23:42:34.8460  2020-01-31 23:45:55.8780
# 26018           300  2020-01-31 23:45:00.6800  2020-01-31 23:50:00.8740
# 26019           721  2020-01-31 23:48:35.1700  2020-02-01 00:00:36.4060
#
#        start station id          start station name  start station latitude  \
# ...

# %%
feb2020
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               841  2020-02-01 00:02:13.7650  2020-02-01 00:16:15.4720
# 1               206  2020-02-01 00:16:11.3850  2020-02-01 00:19:37.4460
# 2               859  2020-02-01 00:23:22.1090  2020-02-01 00:37:41.5060
# 3               693  2020-02-01 00:25:14.5170  2020-02-01 00:36:48.0280
# 4              1473  2020-02-01 00:32:30.5050  2020-02-01 00:57:04.3740
# ...             ...                       ...                       ...
# 22957           262  2020-02-29 23:40:53.1620  2020-02-29 23:45:15.3180
# 22958           216  2020-02-29 23:41:01.3350  2020-02-29 23:44:38.0350
# 22959           101  2020-02-29 23:45:22.1700  2020-02-29 23:47:03.2970
# 22960           279  2020-02-29 23:47:56.8380  2020-02-29 23:52:36.6400
# 22961           212  2020-02-29 23:49:18.4510  2020-02-29 23:52:50.7490
#
#        start station id  start station name  start station latitude  \
# ...

# %%
combined = pd.concat([jan2020, feb2020, mar2020, april2020, may2020, june2020, july2020, aug2020, sept2020, oct2020, nov2020, dec2020]).reset_index()

# %%
combined
# Out:
#         index  tripduration                 starttime  \
# 0           0           226  2020-01-01 00:04:50.1920
# 1           1           377  2020-01-01 00:16:01.6700
# 2           2           288  2020-01-01 00:17:33.8770
# 3           3           435  2020-01-01 00:32:05.9020
# 4           4           231  2020-01-01 00:46:19.6780
# ...       ...           ...                       ...
# 336797  11689          1750  2020-12-31 23:07:44.0030
# 336798  11690          1519  2020-12-31 23:18:00.2630
# 336799  11691          1761  2020-12-31 23:31:09.4620
# 336800  11692           637  2020-12-31 23:35:45.4640
# 336801  11693          1607  2020-12-31 23:48:34.5750
#
#                         stoptime  start station id start station name  \
# 0       2020-01-01 00:08:37.0370              3186      Grove St PATH
# 1       2020-01-01 00:22:19.0800              3186      Grove St PATH
# 2       2020-01-01 00:22:22.4420              3186      Grove St PATH
# ...

# %%
combined.to_csv('combined2020bikedata.csv', encoding='utf-8', index=False)
